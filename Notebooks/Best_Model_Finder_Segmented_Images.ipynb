# %%
# All imports
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import inspect
from tqdm import tqdm
from fastai.imports import *
from fastai.vision.all import *
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.metrics import SparseCategoricalCrossentropy
from tensorflow import keras
from PIL import Image
from numpy import asarray
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import train_test_split
from google.colab.patches import cv2_imshow
from scipy.io import loadmat 
import cv2
import gc

# %%
# Retrieving files from our Google Drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Unzipping files into colab
# !unzip '/content/drive/My Drive/NNDL/group project/segmim.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: segmim/segmim_01026.jpg
#   inflating: __MACOSX/segmim/._segmim_01026.jpg
#   inflating: segmim/segmim_06991.jpg
#   inflating: __MACOSX/segmim/._segmim_06991.jpg
#   inflating: segmim/segmim_00338.jpg
#   inflating: __MACOSX/segmim/._segmim_00338.jpg
#   inflating: segmim/segmim_07457.jpg
#   inflating: __MACOSX/segmim/._segmim_07457.jpg
#   inflating: segmim/segmim_07331.jpg
#   inflating: __MACOSX/segmim/._segmim_07331.jpg
#   inflating: segmim/segmim_08002.jpg
#   inflating: __MACOSX/segmim/._segmim_08002.jpg
#   inflating: segmim/segmim_01998.jpg
#   inflating: __MACOSX/segmim/._segmim_01998.jpg
#   inflating: segmim/segmim_01740.jpg
#   inflating: __MACOSX/segmim/._segmim_01740.jpg
#   inflating: segmim/segmim_05526.jpg
#   inflating: __MACOSX/segmim/._segmim_05526.jpg
#   inflating: segmim/segmim_02249.jpg
#   inflating: __MACOSX/segmim/._segmim_02249.jpg
#   inflating: segmim/segmim_03157.jpg
#   inflating: __MACOSX/segmim/._segmim_03157.jpg
#   inflating: segmim/segmim_04638.jpg
#   inflating: __MACOSX/segmim/._segmim_04638.jpg
#   inflating: segmim/segmim_05532.jpg
#   inflating: __MACOSX/segmim/._segmim_05532.jpg
#   inflating: segmim/segmim_03143.jpg
#   inflating: __MACOSX/segmim/._segmim_03143.jpg
#   inflating: segmim/segmim_07325.jpg
#   inflating: __MACOSX/segmim/._segmim_07325.jpg
#   inflating: segmim/segmim_08016.jpg
#   inflating: __MACOSX/segmim/._segmim_08016.jpg
#   inflating: segmim/segmim_01754.jpg
#   inflating: __MACOSX/segmim/._segmim_01754.jpg
#   inflating: segmim/segmim_01032.jpg
#   inflating: __MACOSX/segmim/._segmim_01032.jpg
#   inflating: segmim/segmim_06985.jpg
#   inflating: __MACOSX/segmim/._segmim_06985.jpg
#   inflating: segmim/segmim_07443.jpg
#   inflating: __MACOSX/segmim/._segmim_07443.jpg
#   inflating: segmim/segmim_03625.jpg
#   inflating: __MACOSX/segmim/._segmim_03625.jpg
#   inflating: segmim/segmim_05254.jpg
#   inflating: __MACOSX/segmim/._segmim_05254.jpg
#   inflating: segmim/segmim_05903.jpg
#   inflating: __MACOSX/segmim/._segmim_05903.jpg
#   inflating: segmim/segmim_07872.jpg
#   inflating: __MACOSX/segmim/._segmim_07872.jpg
#   inflating: segmim/segmim_07866.jpg
#   inflating: __MACOSX/segmim/._segmim_07866.jpg
#   inflating: segmim/segmim_05917.jpg
#   inflating: __MACOSX/segmim/._segmim_05917.jpg
#   inflating: segmim/segmim_00847.jpg
#   inflating: __MACOSX/segmim/._segmim_00847.jpg
#   inflating: segmim/segmim_01581.jpg
#   inflating: __MACOSX/segmim/._segmim_01581.jpg
#   inflating: segmim/segmim_02088.jpg
#   inflating: __MACOSX/segmim/._segmim_02088.jpg
#   inflating: segmim/segmim_03396.jpg
#   inflating: __MACOSX/segmim/._segmim_03396.jpg
#   inflating: segmim/segmim_02936.jpg
#   inflating: __MACOSX/segmim/._segmim_02936.jpg
#   inflating: segmim/segmim_05081.jpg
#   inflating: __MACOSX/segmim/._segmim_05081.jpg
#   inflating: segmim/segmim_06588.jpg
#   inflating: __MACOSX/segmim/._segmim_06588.jpg
#   inflating: segmim/segmim_07696.jpg
#   inflating: __MACOSX/segmim/._segmim_07696.jpg
#   inflating: segmim/segmim_07682.jpg
#   inflating: __MACOSX/segmim/._segmim_07682.jpg
#   inflating: segmim/segmim_02922.jpg
#   inflating: __MACOSX/segmim/._segmim_02922.jpg
#   inflating: segmim/segmim_05095.jpg
#   inflating: __MACOSX/segmim/._segmim_05095.jpg
#   inflating: segmim/segmim_03382.jpg
#   inflating: __MACOSX/segmim/._segmim_03382.jpg
#   inflating: segmim/segmim_00853.jpg
#   inflating: __MACOSX/segmim/._segmim_00853.jpg
#   inflating: segmim/segmim_01595.jpg
#   inflating: __MACOSX/segmim/._segmim_01595.jpg
#   inflating: segmim/segmim_06211.jpg
#   inflating: __MACOSX/segmim/._segmim_06211.jpg
#   inflating: segmim/segmim_00660.jpg
#   inflating: __MACOSX/segmim/._segmim_00660.jpg
#   inflating: segmim/segmim_04406.jpg
#   inflating: __MACOSX/segmim/._segmim_04406.jpg
#   inflating: segmim/segmim_03369.jpg
#   inflating: __MACOSX/segmim/._segmim_03369.jpg
#   inflating: segmim/segmim_02077.jpg
#   inflating: __MACOSX/segmim/._segmim_02077.jpg
#   inflating: segmim/segmim_05718.jpg
#   inflating: __MACOSX/segmim/._segmim_05718.jpg
#   inflating: segmim/segmim_02711.jpg
#   inflating: __MACOSX/segmim/._segmim_02711.jpg
#   inflating: segmim/segmim_04360.jpg
#   inflating: __MACOSX/segmim/._segmim_04360.jpg
#   inflating: segmim/segmim_07669.jpg
#   inflating: __MACOSX/segmim/._segmim_07669.jpg
#   inflating: segmim/segmim_00106.jpg
#   inflating: __MACOSX/segmim/._segmim_00106.jpg
#   inflating: segmim/segmim_01218.jpg
#   inflating: __MACOSX/segmim/._segmim_01218.jpg
#   inflating: segmim/segmim_06577.jpg
#   inflating: __MACOSX/segmim/._segmim_06577.jpg
#   inflating: segmim/segmim_00112.jpg
#   inflating: __MACOSX/segmim/._segmim_00112.jpg
#   inflating: segmim/segmim_06563.jpg
#   inflating: __MACOSX/segmim/._segmim_06563.jpg
#   inflating: segmim/segmim_02705.jpg
#   inflating: __MACOSX/segmim/._segmim_02705.jpg
#   inflating: segmim/segmim_04374.jpg
#   inflating: segmim/segmim_05863.jpg
#   inflating: __MACOSX/segmim/._segmim_05863.jpg
#   inflating: segmim/segmim_00933.jpg
#   inflating: __MACOSX/segmim/._segmim_00933.jpg
#   inflating: segmim/segmim_07084.jpg
#   inflating: __MACOSX/segmim/._segmim_07084.jpg
#   inflating: segmim/segmim_05693.jpg
#   inflating: __MACOSX/segmim/._segmim_05693.jpg
#   inflating: segmim/segmim_02842.jpg
#   inflating: __MACOSX/segmim/._segmim_02842.jpg
#   inflating: segmim/segmim_03584.jpg
#   inflating: __MACOSX/segmim/._segmim_03584.jpg
#   inflating: segmim/segmim_01393.jpg
#   inflating: __MACOSX/segmim/._segmim_01393.jpg
#   inflating: segmim/segmim_00099.jpg
#   inflating: __MACOSX/segmim/._segmim_00099.jpg
#   inflating: segmim/segmim_01387.jpg
#   inflating: __MACOSX/segmim/._segmim_01387.jpg
#   inflating: segmim/segmim_02856.jpg
#   inflating: __MACOSX/segmim/._segmim_02856.jpg
#   inflating: segmim/segmim_03590.jpg
#   inflating: __MACOSX/segmim/._segmim_03590.jpg
#   inflating: segmim/segmim_04599.jpg
#   inflating: __MACOSX/segmim/._segmim_04599.jpg
#   inflating: segmim/segmim_05687.jpg
#   inflating: __MACOSX/segmim/._segmim_05687.jpg
#   inflating: segmim/segmim_00927.jpg
#   inflating: __MACOSX/segmim/._segmim_00927.jpg
#   inflating: segmim/segmim_07090.jpg
#   inflating: __MACOSX/segmim/._segmim_07090.jpg
#   inflating: segmim/segmim_00714.jpg
#   inflating: __MACOSX/segmim/._segmim_00714.jpg
#   inflating: segmim/segmim_06365.jpg
#   inflating: __MACOSX/segmim/._segmim_06365.jpg
#   inflating: segmim/segmim_02103.jpg
#   inflating: __MACOSX/segmim/._segmim_02103.jpg
#   inflating: segmim/segmim_04572.jpg
#   inflating: __MACOSX/segmim/._segmim_04572.jpg
#   inflating: segmim/segmim_04214.jpg
#   inflating: __MACOSX/segmim/._segmim_04214.jpg
#   inflating: segmim/segmim_02665.jpg
#   inflating: __MACOSX/segmim/._segmim_02665.jpg
#   inflating: segmim/segmim_06403.jpg
#   inflating: __MACOSX/segmim/._segmim_06403.jpg
#   inflating: segmim/segmim_00072.jpg
#   inflating: __MACOSX/segmim/._segmim_00072.jpg
#   inflating: segmim/segmim_06417.jpg
#   inflating: __MACOSX/segmim/._segmim_06417.jpg
#   inflating: segmim/segmim_01378.jpg
#   inflating: __MACOSX/segmim/._segmim_01378.jpg
#   inflating: segmim/segmim_00066.jpg
#   inflating: __MACOSX/segmim/._segmim_00066.jpg
#   inflating: segmim/segmim_07709.jpg
#   inflating: __MACOSX/segmim/._segmim_07709.jpg
#   inflating: segmim/segmim_04200.jpg
#   inflating: __MACOSX/segmim/._segmim_04200.jpg
#   inflating: segmim/segmim_02671.jpg
#   inflating: __MACOSX/segmim/._segmim_02671.jpg
#   inflating: segmim/segmim_05678.jpg
#   inflating: __MACOSX/segmim/._segmim_05678.jpg
#   inflating: segmim/segmim_02117.jpg
#   inflating: __MACOSX/segmim/._segmim_02117.jpg
#   inflating: segmim/segmim_03209.jpg
#   inflating: __MACOSX/segmim/._segmim_03209.jpg
#   inflating: segmim/segmim_04566.jpg
#   inflating: __MACOSX/segmim/._segmim_04566.jpg
#   inflating: segmim/segmim_00700.jpg
#   inflating: __MACOSX/segmim/._segmim_00700.jpg
#   inflating: segmim/segmim_06371.jpg
#   inflating: __MACOSX/segmim/._segmim_06371.jpg
#   inflating: segmim/segmim_05650.jpg
#   inflating: __MACOSX/segmim/._segmim_05650.jpg
#   inflating: segmim/segmim_05888.jpg
#   inflating: __MACOSX/segmim/._segmim_05888.jpg
#   inflating: segmim/segmim_03221.jpg
#   inflating: __MACOSX/segmim/._segmim_03221.jpg
#   inflating: segmim/segmim_07047.jpg
#   inflating: __MACOSX/segmim/._segmim_07047.jpg
#   inflating: segmim/segmim_00728.jpg
#   inflating: __MACOSX/segmim/._segmim_00728.jpg
#   inflating: segmim/segmim_01436.jpg
#   inflating: __MACOSX/segmim/._segmim_01436.jpg
#   inflating: segmim/segmim_06359.jpg
#   inflating: __MACOSX/segmim/._segmim_06359.jpg
#   inflating: segmim/segmim_01350.jpg
#   inflating: __MACOSX/segmim/._segmim_01350.jpg
#   inflating: segmim/segmim_07721.jpg
#   inflating: __MACOSX/segmim/._segmim_07721.jpg
#   inflating: segmim/segmim_04228.jpg
#   inflating: __MACOSX/segmim/._segmim_04228.jpg
#   inflating: segmim/segmim_02881.jpg
#   inflating: __MACOSX/segmim/._segmim_02881.jpg
#   inflating: segmim/segmim_03547.jpg
#   inflating: __MACOSX/segmim/._segmim_03547.jpg
#   inflating: segmim/segmim_02659.jpg
#   inflating: __MACOSX/segmim/._segmim_02659.jpg
#   inflating: segmim/segmim_05136.jpg
#   inflating: __MACOSX/segmim/._segmim_05136.jpg
#   inflating: segmim/segmim_02895.jpg
#   inflating: __MACOSX/segmim/._segmim_02895.jpg
#   inflating: segmim/segmim_03553.jpg
#   inflating: __MACOSX/segmim/._segmim_03553.jpg
#   inflating: segmim/segmim_05122.jpg
#   inflating: __MACOSX/segmim/._segmim_05122.jpg
#   inflating: segmim/segmim_01344.jpg
#   inflating: __MACOSX/segmim/._segmim_01344.jpg
#   inflating: segmim/segmim_07735.jpg
#   inflating: __MACOSX/segmim/._segmim_07735.jpg
#   inflating: segmim/segmim_07053.jpg
#   inflating: __MACOSX/segmim/._segmim_07053.jpg
#   inflating: segmim/segmim_01422.jpg
#   inflating: __MACOSX/segmim/._segmim_01422.jpg
#   inflating: segmim/segmim_05644.jpg
#   inflating: __MACOSX/segmim/._segmim_05644.jpg
#   inflating: segmim/segmim_03235.jpg
#   inflating: __MACOSX/segmim/._segmim_03235.jpg
#   inflating: segmim/segmim_03962.jpg
#   inflating: __MACOSX/segmim/._segmim_03962.jpg
#   inflating: segmim/segmim_08189.jpg
#   inflating: __MACOSX/segmim/._segmim_08189.jpg
#   inflating: segmim/segmim_06614.jpg
#   inflating: __MACOSX/segmim/._segmim_06614.jpg
#   inflating: segmim/segmim_00265.jpg
#   inflating: __MACOSX/segmim/._segmim_00265.jpg
#   inflating: segmim/segmim_04003.jpg
#   inflating: __MACOSX/segmim/._segmim_04003.jpg
#   inflating: segmim/segmim_02472.jpg
#   inflating: __MACOSX/segmim/._segmim_02472.jpg
#   inflating: segmim/segmim_04017.jpg
#   inflating: __MACOSX/segmim/._segmim_04017.jpg
#   inflating: segmim/segmim_03778.jpg
#   inflating: __MACOSX/segmim/._segmim_03778.jpg
#   inflating: segmim/segmim_02466.jpg
#   inflating: __MACOSX/segmim/._segmim_02466.jpg
#   inflating: segmim/segmim_05309.jpg
#   inflating: __MACOSX/segmim/._segmim_05309.jpg
#   inflating: segmim/segmim_06600.jpg
#   inflating: __MACOSX/segmim/._segmim_06600.jpg
#   inflating: segmim/segmim_00271.jpg
#   inflating: __MACOSX/segmim/._segmim_00271.jpg
#   inflating: segmim/segmim_07278.jpg
#   inflating: __MACOSX/segmim/._segmim_07278.jpg
#   inflating: segmim/segmim_00517.jpg
#   inflating: __MACOSX/segmim/._segmim_00517.jpg
#   inflating: segmim/segmim_01609.jpg
#   inflating: __MACOSX/segmim/._segmim_01609.jpg
#   inflating: segmim/segmim_06166.jpg
#   inflating: __MACOSX/segmim/._segmim_06166.jpg
#   inflating: segmim/segmim_02300.jpg
#   inflating: __MACOSX/segmim/._segmim_02300.jpg
#   inflating: segmim/segmim_04771.jpg
#   inflating: __MACOSX/segmim/._segmim_04771.jpg
#   inflating: segmim/segmim_05484.jpg
#   inflating: __MACOSX/segmim/._segmim_05484.jpg
#   inflating: segmim/segmim_04942.jpg
#   inflating: __MACOSX/segmim/._segmim_04942.jpg
#   inflating: segmim/segmim_07293.jpg
#   inflating: __MACOSX/segmim/._segmim_07293.jpg
#   inflating: segmim/segmim_06833.jpg
#   inflating: __MACOSX/segmim/._segmim_06833.jpg
#   inflating: segmim/segmim_01184.jpg
#   inflating: __MACOSX/segmim/._segmim_01184.jpg
#   inflating: segmim/segmim_03793.jpg
#   inflating: __MACOSX/segmim/._segmim_03793.jpg
#   inflating: segmim/segmim_02499.jpg
#   inflating: __MACOSX/segmim/._segmim_02499.jpg
#   inflating: segmim/segmim_03787.jpg
#   inflating: __MACOSX/segmim/._segmim_03787.jpg
#   inflating: segmim/segmim_06827.jpg
#   inflating: __MACOSX/segmim/._segmim_06827.jpg
#   inflating: segmim/segmim_01190.jpg
#   inflating: __MACOSX/segmim/._segmim_01190.jpg
#   inflating: segmim/segmim_06199.jpg
#   inflating: __MACOSX/segmim/._segmim_06199.jpg
#   inflating: segmim/segmim_07287.jpg
#   inflating: __MACOSX/segmim/._segmim_07287.jpg
#   inflating: segmim/segmim_05490.jpg
#   inflating: __MACOSX/segmim/._segmim_05490.jpg
#   inflating: segmim/segmim_04956.jpg
#   inflating: __MACOSX/segmim/._segmim_04956.jpg
#   inflating: __MACOSX/segmim/._segmim_07708.jpg
#   inflating: segmim/segmim_00067.jpg
#   inflating: __MACOSX/segmim/._segmim_00067.jpg
#   inflating: segmim/segmim_01379.jpg
#   inflating: __MACOSX/segmim/._segmim_01379.jpg
#   inflating: segmim/segmim_06416.jpg
#   inflating: __MACOSX/segmim/._segmim_06416.jpg
#   inflating: segmim/segmim_06370.jpg
#   inflating: __MACOSX/segmim/._segmim_06370.jpg
#   inflating: segmim/segmim_00701.jpg
#   inflating: __MACOSX/segmim/._segmim_00701.jpg
#   inflating: segmim/segmim_04567.jpg
#   inflating: __MACOSX/segmim/._segmim_04567.jpg
#   inflating: segmim/segmim_03208.jpg
#   inflating: __MACOSX/segmim/._segmim_03208.jpg
#   inflating: segmim/segmim_02116.jpg
#   inflating: __MACOSX/segmim/._segmim_02116.jpg
#   inflating: segmim/segmim_05679.jpg
#   inflating: __MACOSX/segmim/._segmim_05679.jpg
#   inflating: segmim/segmim_04573.jpg
#   inflating: __MACOSX/segmim/._segmim_04573.jpg
#   inflating: segmim/segmim_02102.jpg
#   inflating: __MACOSX/segmim/._segmim_02102.jpg
#   inflating: segmim/segmim_06364.jpg
#   inflating: __MACOSX/segmim/._segmim_06364.jpg
#   inflating: segmim/segmim_00715.jpg
#   inflating: __MACOSX/segmim/._segmim_00715.jpg
#   inflating: segmim/segmim_00073.jpg
#   inflating: __MACOSX/segmim/._segmim_00073.jpg
#   inflating: segmim/segmim_06402.jpg
#   inflating: __MACOSX/segmim/._segmim_06402.jpg
#   inflating: segmim/segmim_02664.jpg
#   inflating: __MACOSX/segmim/._segmim_02664.jpg
#   inflating: segmim/segmim_04215.jpg
#   inflating: __MACOSX/segmim/._segmim_04215.jpg
#   inflating: segmim/segmim_03591.jpg
#   inflating: __MACOSX/segmim/._segmim_03591.jpg
#   inflating: segmim/segmim_02857.jpg
#   inflating: __MACOSX/segmim/._segmim_02857.jpg
#   inflating: segmim/segmim_01386.jpg
#   inflating: __MACOSX/segmim/._segmim_01386.jpg
#   inflating: segmim/segmim_00098.jpg
#   inflating: __MACOSX/segmim/._segmim_00098.jpg
#   inflating: segmim/segmim_07091.jpg
#   inflating: __MACOSX/segmim/._segmim_07091.jpg
#   inflating: segmim/segmim_00926.jpg
#   inflating: __MACOSX/segmim/._segmim_00926.jpg
#   inflating: segmim/segmim_05686.jpg
#   inflating: __MACOSX/segmim/._segmim_05686.jpg
#   inflating: segmim/segmim_04598.jpg
#   inflating: __MACOSX/segmim/._segmim_04598.jpg
#   inflating: segmim/segmim_05692.jpg
#   inflating: __MACOSX/segmim/._segmim_05692.jpg
#   inflating: segmim/segmim_07085.jpg
#   inflating: __MACOSX/segmim/._segmim_07085.jpg
#   inflating: segmim/segmim_00932.jpg
#   inflating: __MACOSX/segmim/._segmim_00932.jpg
#   inflating: segmim/segmim_01392.jpg
#   inflating: __MACOSX/segmim/._segmim_01392.jpg
#   inflating: segmim/segmim_03585.jpg
#   inflating: __MACOSX/segmim/._segmim_03585.jpg
#   inflating: segmim/segmim_02843.jpg
#   inflating: __MACOSX/segmim/._segmim_02843.jpg
#   inflating: segmim/segmim_07913.jpg
#   inflating: __MACOSX/segmim/._segmim_07913.jpg
#   inflating: segmim/segmim_05862.jpg
#   inflating: __MACOSX/segmim/._segmim_05862.jpg
#   inflating: segmim/segmim_05876.jpg
#   inflating: __MACOSX/segmim/._segmim_05876.jpg
#   inflating: segmim/segmim_07907.jpg
#   inflating: __MACOSX/segmim/._segmim_07907.jpg
#   inflating: segmim/segmim_07898.jpg
#   inflating: __MACOSX/segmim/._segmim_07898.jpg
#   inflating: segmim/segmim_01231.jpg
#   inflating: __MACOSX/segmim/._segmim_01231.jpg
#   inflating: segmim/segmim_07640.jpg
#   inflating: __MACOSX/segmim/._segmim_07640.jpg
#   inflating: segmim/segmim_04349.jpg
#   inflating: __MACOSX/segmim/._segmim_04349.jpg
#   inflating: segmim/segmim_03426.jpg
#   inflating: __MACOSX/segmim/._segmim_03426.jpg
#   inflating: segmim/segmim_02738.jpg
#   inflating: __MACOSX/segmim/._segmim_02738.jpg
#   inflating: segmim/segmim_05057.jpg
#   inflating: __MACOSX/segmim/._segmim_05057.jpg
#   inflating: segmim/segmim_05731.jpg
#   inflating: __MACOSX/segmim/._segmim_05731.jpg
#   inflating: segmim/segmim_03340.jpg
#   inflating: __MACOSX/segmim/._segmim_03340.jpg
#   inflating: segmim/segmim_07126.jpg
#   inflating: __MACOSX/segmim/._segmim_07126.jpg
#   inflating: segmim/segmim_00649.jpg
#   inflating: __MACOSX/segmim/._segmim_00649.jpg
#   inflating: segmim/segmim_01557.jpg
#   inflating: __MACOSX/segmim/._segmim_01557.jpg
#   inflating: segmim/segmim_06238.jpg
#   inflating: __MACOSX/segmim/._segmim_06238.jpg
#   inflating: segmim/segmim_00891.jpg
#   inflating: __MACOSX/segmim/._segmim_00891.jpg
#   inflating: segmim/segmim_07132.jpg
#   inflating: __MACOSX/segmim/._segmim_07132.jpg
#   inflating: segmim/segmim_01543.jpg
#   inflating: __MACOSX/segmim/._segmim_01543.jpg
#   inflating: segmim/segmim_00885.jpg
#   inflating: __MACOSX/segmim/._segmim_00885.jpg
#   inflating: segmim/segmim_05725.jpg
#   inflating: __MACOSX/segmim/._segmim_05725.jpg
#   inflating: segmim/segmim_03354.jpg
#   inflating: __MACOSX/segmim/._segmim_03354.jpg
#   inflating: segmim/segmim_03432.jpg
#   inflating: __MACOSX/segmim/._segmim_03432.jpg
#   inflating: segmim/segmim_05043.jpg
#   inflating: __MACOSX/segmim/._segmim_05043.jpg
#   inflating: segmim/segmim_01225.jpg
#   inflating: __MACOSX/segmim/._segmim_01225.jpg
#   inflating: segmim/segmim_07654.jpg
#   inflating: __MACOSX/segmim/._segmim_07654.jpg
#   inflating: segmim/segmim_04375.jpg
#   inflating: __MACOSX/segmim/._segmim_04375.jpg
#   inflating: segmim/segmim_02704.jpg
#   inflating: __MACOSX/segmim/._segmim_02704.jpg
#   inflating: segmim/segmim_06562.jpg
#   inflating: __MACOSX/segmim/._segmim_06562.jpg
#   inflating: segmim/segmim_00113.jpg
#   inflating: __MACOSX/segmim/._segmim_00113.jpg
#   inflating: segmim/segmim_00675.jpg
#   inflating: __MACOSX/segmim/._segmim_00675.jpg
#   inflating: segmim/segmim_06204.jpg
#   inflating: __MACOSX/segmim/._segmim_06204.jpg
#   inflating: segmim/segmim_02062.jpg
#   inflating: __MACOSX/segmim/._segmim_02062.jpg
#   inflating: segmim/segmim_04413.jpg
#   inflating: __MACOSX/segmim/._segmim_04413.jpg
#   inflating: segmim/segmim_05719.jpg
#   inflating: __MACOSX/segmim/._segmim_05719.jpg
#   inflating: segmim/segmim_02076.jpg
#   inflating: __MACOSX/segmim/._segmim_02076.jpg
#   inflating: segmim/segmim_03368.jpg
#   inflating: __MACOSX/segmim/._segmim_03368.jpg
#   inflating: segmim/segmim_04407.jpg
#   inflating: __MACOSX/segmim/._segmim_04407.jpg
#   inflating: segmim/segmim_00661.jpg
#   inflating: __MACOSX/segmim/._segmim_00661.jpg
#   inflating: segmim/segmim_06210.jpg
#   inflating: __MACOSX/segmim/._segmim_06210.jpg
#   inflating: segmim/segmim_06576.jpg
#   inflating: __MACOSX/segmim/._segmim_06576.jpg
#   inflating: segmim/segmim_01219.jpg
#   inflating: __MACOSX/segmim/._segmim_01219.jpg
#   inflating: segmim/segmim_00107.jpg
#   inflating: __MACOSX/segmim/._segmim_00107.jpg
#   inflating: segmim/segmim_07668.jpg
#   inflating: __MACOSX/segmim/._segmim_07668.jpg
#   inflating: segmim/segmim_04361.jpg
#   inflating: __MACOSX/segmim/._segmim_04361.jpg
#   inflating: segmim/segmim_02710.jpg
#   inflating: __MACOSX/segmim/._segmim_02710.jpg
#   inflating: segmim/segmim_05094.jpg
#   inflating: __MACOSX/segmim/._segmim_05094.jpg
#   inflating: segmim/segmim_02923.jpg
#   inflating: __MACOSX/segmim/._segmim_02923.jpg
#   inflating: segmim/segmim_07683.jpg
#   inflating: __MACOSX/segmim/._segmim_07683.jpg
#   inflating: segmim/segmim_01594.jpg
#   inflating: __MACOSX/segmim/._segmim_01594.jpg
#   inflating: segmim/segmim_00852.jpg
#   inflating: __MACOSX/segmim/._segmim_00852.jpg
#   inflating: segmim/segmim_03383.jpg
#   inflating: __MACOSX/segmim/._segmim_03383.jpg
#   inflating: segmim/segmim_03397.jpg
#   inflating: __MACOSX/segmim/._segmim_03397.jpg
#   inflating: segmim/segmim_02089.jpg
#   inflating: __MACOSX/segmim/._segmim_02089.jpg
#   inflating: segmim/segmim_01580.jpg
#   inflating: __MACOSX/segmim/._segmim_01580.jpg
#   inflating: segmim/segmim_00846.jpg
#   inflating: __MACOSX/segmim/._segmim_00846.jpg
#   inflating: segmim/segmim_07697.jpg
#   inflating: __MACOSX/segmim/._segmim_07697.jpg
#   inflating: segmim/segmim_06589.jpg
#   inflating: __MACOSX/segmim/._segmim_06589.jpg
#   inflating: __MACOSX/segmim/._segmim_07330.jpg
#   inflating: segmim/segmim_04611.jpg
#   inflating: __MACOSX/segmim/._segmim_04611.jpg
#   inflating: segmim/segmim_02260.jpg
#   inflating: __MACOSX/segmim/._segmim_02260.jpg
#   inflating: segmim/segmim_06006.jpg
#   inflating: __MACOSX/segmim/._segmim_06006.jpg
#   inflating: segmim/segmim_01769.jpg
#   inflating: __MACOSX/segmim/._segmim_01769.jpg
#   inflating: segmim/segmim_00477.jpg
#   inflating: __MACOSX/segmim/._segmim_00477.jpg
#   inflating: segmim/segmim_07318.jpg
#   inflating: __MACOSX/segmim/._segmim_07318.jpg
#   inflating: segmim/segmim_00311.jpg
#   inflating: __MACOSX/segmim/._segmim_00311.jpg
#   inflating: segmim/segmim_06760.jpg
#   inflating: __MACOSX/segmim/._segmim_06760.jpg
#   inflating: segmim/segmim_05269.jpg
#   inflating: __MACOSX/segmim/._segmim_05269.jpg
#   inflating: segmim/segmim_02506.jpg
#   inflating: __MACOSX/segmim/._segmim_02506.jpg
#   inflating: segmim/segmim_03618.jpg
#   inflating: __MACOSX/segmim/._segmim_03618.jpg
#   inflating: segmim/segmim_04177.jpg
#   inflating: __MACOSX/segmim/._segmim_04177.jpg
#   inflating: segmim/segmim_02512.jpg
#   inflating: __MACOSX/segmim/._segmim_02512.jpg
#   inflating: segmim/segmim_04163.jpg
#   inflating: __MACOSX/segmim/._segmim_04163.jpg
#   inflating: segmim/segmim_00305.jpg
#   inflating: __MACOSX/segmim/._segmim_00305.jpg
#   inflating: segmim/segmim_06774.jpg
#   inflating: __MACOSX/segmim/._segmim_06774.jpg
#   inflating: segmim/segmim_06012.jpg
#   inflating: __MACOSX/segmim/._segmim_06012.jpg
#   inflating: segmim/segmim_00463.jpg
#   inflating: __MACOSX/segmim/._segmim_00463.jpg
#   inflating: segmim/segmim_04605.jpg
#   inflating: __MACOSX/segmim/._segmim_04605.jpg
#   inflating: segmim/segmim_02274.jpg
#   inflating: __MACOSX/segmim/._segmim_02274.jpg
#   inflating: segmim/segmim_04836.jpg
#   inflating: __MACOSX/segmim/._segmim_04836.jpg
#   inflating: segmim/segmim_03181.jpg
#   inflating: __MACOSX/segmim/._segmim_03181.jpg
#   inflating: segmim/segmim_00488.jpg
#   inflating: __MACOSX/segmim/._segmim_00488.jpg
#   inflating: segmim/segmim_01796.jpg
#   inflating: __MACOSX/segmim/._segmim_01796.jpg
#   inflating: segmim/segmim_07481.jpg
#   inflating: __MACOSX/segmim/._segmim_07481.jpg
#   inflating: segmim/segmim_06947.jpg
#   inflating: __MACOSX/segmim/._segmim_06947.jpg
#   inflating: segmim/segmim_04188.jpg
#   inflating: __MACOSX/segmim/._segmim_04188.jpg
#   inflating: segmim/segmim_05296.jpg
#   inflating: __MACOSX/segmim/._segmim_05296.jpg
#   inflating: segmim/segmim_05282.jpg
#   inflating: __MACOSX/segmim/._segmim_05282.jpg
#   inflating: segmim/segmim_07495.jpg
#   inflating: segmim/segmim_06075.jpg
#   inflating: __MACOSX/segmim/._segmim_06075.jpg
#   inflating: segmim/segmim_02213.jpg
#   inflating: __MACOSX/segmim/._segmim_02213.jpg
#   inflating: segmim/segmim_04662.jpg
#   inflating: __MACOSX/segmim/._segmim_04662.jpg
#   inflating: segmim/segmim_02207.jpg
#   inflating: __MACOSX/segmim/._segmim_02207.jpg
#   inflating: segmim/segmim_05568.jpg
#   inflating: __MACOSX/segmim/._segmim_05568.jpg
#   inflating: segmim/segmim_04676.jpg
#   inflating: __MACOSX/segmim/._segmim_04676.jpg
#   inflating: segmim/segmim_03119.jpg
#   inflating: __MACOSX/segmim/._segmim_03119.jpg
#   inflating: segmim/segmim_00410.jpg
#   inflating: __MACOSX/segmim/._segmim_00410.jpg
#   inflating: segmim/segmim_06061.jpg
#   inflating: __MACOSX/segmim/._segmim_06061.jpg
#   inflating: segmim/segmim_01068.jpg
#   inflating: __MACOSX/segmim/._segmim_01068.jpg
#   inflating: segmim/segmim_06707.jpg
#   inflating: __MACOSX/segmim/._segmim_06707.jpg
#   inflating: segmim/segmim_07419.jpg
#   inflating: __MACOSX/segmim/._segmim_07419.jpg
#   inflating: segmim/segmim_00376.jpg
#   inflating: __MACOSX/segmim/._segmim_00376.jpg
#   inflating: segmim/segmim_04110.jpg
#   inflating: __MACOSX/segmim/._segmim_04110.jpg
#   inflating: segmim/segmim_02561.jpg
#   inflating: __MACOSX/segmim/._segmim_02561.jpg
#   inflating: segmim/segmim_05781.jpg
#   inflating: __MACOSX/segmim/._segmim_05781.jpg
#   inflating: segmim/segmim_05959.jpg
#   inflating: __MACOSX/segmim/._segmim_05959.jpg
#   inflating: segmim/segmim_07196.jpg
#   inflating: __MACOSX/segmim/._segmim_07196.jpg
#   inflating: segmim/segmim_06288.jpg
#   inflating: __MACOSX/segmim/._segmim_06288.jpg
#   inflating: segmim/segmim_00821.jpg
#   inflating: __MACOSX/segmim/._segmim_00821.jpg
#   inflating: segmim/segmim_07828.jpg
#   inflating: __MACOSX/segmim/._segmim_07828.jpg
#   inflating: segmim/segmim_01281.jpg
#   inflating: __MACOSX/segmim/._segmim_01281.jpg
#   inflating: segmim/segmim_02950.jpg
#   inflating: __MACOSX/segmim/._segmim_02950.jpg
#   inflating: segmim/segmim_03496.jpg
#   inflating: __MACOSX/segmim/._segmim_03496.jpg
#   inflating: segmim/segmim_02788.jpg
#   inflating: __MACOSX/segmim/._segmim_02788.jpg
#   inflating: segmim/segmim_02944.jpg
#   inflating: __MACOSX/segmim/._segmim_02944.jpg
#   inflating: segmim/segmim_03482.jpg
#   inflating: __MACOSX/segmim/._segmim_03482.jpg
#   inflating: segmim/segmim_01295.jpg
#   inflating: __MACOSX/segmim/._segmim_01295.jpg
#   inflating: segmim/segmim_07182.jpg
#   inflating: __MACOSX/segmim/._segmim_07182.jpg
#   inflating: segmim/segmim_00835.jpg
# ...
#   inflating: __MACOSX/segmim/._segmim_05154.jpg
#   inflating: segmim/segmim_03525.jpg
#   inflating: __MACOSX/segmim/._segmim_03525.jpg
#   inflating: segmim/segmim_03243.jpg
#   inflating: __MACOSX/segmim/._segmim_03243.jpg
#   inflating: segmim/segmim_05632.jpg
#   inflating: __MACOSX/segmim/._segmim_05632.jpg
#   inflating: segmim/segmim_00992.jpg
#   inflating: __MACOSX/segmim/._segmim_00992.jpg
#   inflating: segmim/segmim_01454.jpg
#   inflating: __MACOSX/segmim/._segmim_01454.jpg
#   inflating: segmim/segmim_07025.jpg
#   inflating: __MACOSX/segmim/._segmim_07025.jpg
#   inflating: segmim/segmim_04504.jpg
#   inflating: __MACOSX/segmim/._segmim_04504.jpg
#   inflating: segmim/segmim_02175.jpg
#   inflating: __MACOSX/segmim/._segmim_02175.jpg
#   inflating: segmim/segmim_06313.jpg
#   inflating: __MACOSX/segmim/._segmim_06313.jpg
#   inflating: segmim/segmim_00762.jpg
#   inflating: __MACOSX/segmim/._segmim_00762.jpg
#   inflating: segmim/segmim_00004.jpg
#   inflating: __MACOSX/segmim/._segmim_00004.jpg
#   inflating: segmim/segmim_06475.jpg
#   inflating: __MACOSX/segmim/._segmim_06475.jpg
#   inflating: segmim/segmim_02613.jpg
#   inflating: __MACOSX/segmim/._segmim_02613.jpg
#   inflating: segmim/segmim_04262.jpg
#   inflating: __MACOSX/segmim/._segmim_04262.jpg
#   inflating: segmim/segmim_05168.jpg
#   inflating: __MACOSX/segmim/._segmim_05168.jpg
#   inflating: segmim/segmim_02607.jpg
#   inflating: __MACOSX/segmim/._segmim_02607.jpg
#   inflating: segmim/segmim_03519.jpg
#   inflating: __MACOSX/segmim/._segmim_03519.jpg
#   inflating: segmim/segmim_04276.jpg
#   inflating: __MACOSX/segmim/._segmim_04276.jpg
#   inflating: segmim/segmim_00010.jpg
#   inflating: __MACOSX/segmim/._segmim_00010.jpg
#   inflating: segmim/segmim_06461.jpg
#   inflating: __MACOSX/segmim/._segmim_06461.jpg
#   inflating: segmim/segmim_06307.jpg
#   inflating: __MACOSX/segmim/._segmim_06307.jpg
#   inflating: segmim/segmim_01468.jpg
#   inflating: __MACOSX/segmim/._segmim_01468.jpg
#   inflating: segmim/segmim_00776.jpg
#   inflating: __MACOSX/segmim/._segmim_00776.jpg
#   inflating: segmim/segmim_07019.jpg
#   inflating: __MACOSX/segmim/._segmim_07019.jpg
#   inflating: segmim/segmim_04510.jpg
#   inflating: __MACOSX/segmim/._segmim_04510.jpg
#   inflating: segmim/segmim_02161.jpg
#   inflating: __MACOSX/segmim/._segmim_02161.jpg
#   inflating: segmim/segmim_03294.jpg
#   inflating: __MACOSX/segmim/._segmim_03294.jpg
#   inflating: segmim/segmim_00945.jpg
#   inflating: __MACOSX/segmim/._segmim_00945.jpg
#   inflating: segmim/segmim_01483.jpg
#   inflating: __MACOSX/segmim/._segmim_01483.jpg
#   inflating: segmim/segmim_07794.jpg
#   inflating: __MACOSX/segmim/._segmim_07794.jpg
#   inflating: segmim/segmim_02834.jpg
#   inflating: segmim/segmim_02997.jpg
#   inflating: __MACOSX/segmim/._segmim_02997.jpg
#   inflating: segmim/segmim_03451.jpg
#   inflating: __MACOSX/segmim/._segmim_03451.jpg
#   inflating: segmim/segmim_05020.jpg
#   inflating: __MACOSX/segmim/._segmim_05020.jpg
#   inflating: segmim/segmim_05746.jpg
#   inflating: __MACOSX/segmim/._segmim_05746.jpg
#   inflating: segmim/segmim_02029.jpg
#   inflating: __MACOSX/segmim/._segmim_02029.jpg
#   inflating: segmim/segmim_03337.jpg
#   inflating: __MACOSX/segmim/._segmim_03337.jpg
#   inflating: segmim/segmim_04458.jpg
#   inflating: __MACOSX/segmim/._segmim_04458.jpg
#   inflating: segmim/segmim_07151.jpg
#   inflating: __MACOSX/segmim/._segmim_07151.jpg
#   inflating: segmim/segmim_01520.jpg
#   inflating: __MACOSX/segmim/._segmim_01520.jpg
#   inflating: segmim/segmim_02001.jpg
#   inflating: __MACOSX/segmim/._segmim_02001.jpg
#   inflating: segmim/segmim_04470.jpg
#   inflating: __MACOSX/segmim/._segmim_04470.jpg
#   inflating: segmim/segmim_07179.jpg
#   inflating: __MACOSX/segmim/._segmim_07179.jpg
#   inflating: segmim/segmim_00616.jpg
#   inflating: __MACOSX/segmim/._segmim_00616.jpg
#   inflating: segmim/segmim_01508.jpg
#   inflating: __MACOSX/segmim/._segmim_01508.jpg
#   inflating: segmim/segmim_06267.jpg
#   inflating: __MACOSX/segmim/._segmim_06267.jpg
#   inflating: segmim/segmim_06501.jpg
#   inflating: __MACOSX/segmim/._segmim_06501.jpg
#   inflating: segmim/segmim_00170.jpg
#   inflating: __MACOSX/segmim/._segmim_00170.jpg
#   inflating: segmim/segmim_04316.jpg
#   inflating: __MACOSX/segmim/._segmim_04316.jpg
#   inflating: segmim/segmim_03479.jpg
#   inflating: __MACOSX/segmim/._segmim_03479.jpg
#   inflating: segmim/segmim_02767.jpg
#   inflating: __MACOSX/segmim/._segmim_02767.jpg
#   inflating: segmim/segmim_05008.jpg
#   inflating: __MACOSX/segmim/._segmim_05008.jpg
#   inflating: segmim/segmim_04302.jpg
#   inflating: __MACOSX/segmim/._segmim_04302.jpg
#   inflating: segmim/segmim_02773.jpg
#   inflating: __MACOSX/segmim/._segmim_02773.jpg
#   inflating: segmim/segmim_06515.jpg
#   inflating: __MACOSX/segmim/._segmim_06515.jpg
#   inflating: segmim/segmim_00164.jpg
#   inflating: __MACOSX/segmim/._segmim_00164.jpg
#   inflating: segmim/segmim_00602.jpg
#   inflating: __MACOSX/segmim/._segmim_00602.jpg
#   inflating: segmim/segmim_06273.jpg
#   inflating: __MACOSX/segmim/._segmim_06273.jpg
#   inflating: segmim/segmim_02015.jpg
#   inflating: __MACOSX/segmim/._segmim_02015.jpg
#   inflating: segmim/segmim_04464.jpg
#   inflating: __MACOSX/segmim/._segmim_04464.jpg
#   inflating: segmim/segmim_05949.jpg
#   inflating: __MACOSX/segmim/._segmim_05949.jpg
#   inflating: __MACOSX/segmim/._segmim_07409.jpg
#   inflating: segmim/segmim_00366.jpg
#   inflating: __MACOSX/segmim/._segmim_00366.jpg
#   inflating: segmim/segmim_01078.jpg
#   inflating: __MACOSX/segmim/._segmim_01078.jpg
#   inflating: segmim/segmim_06717.jpg
#   inflating: __MACOSX/segmim/._segmim_06717.jpg
#   inflating: segmim/segmim_02571.jpg
#   inflating: __MACOSX/segmim/._segmim_02571.jpg
#   inflating: segmim/segmim_04100.jpg
#   inflating: __MACOSX/segmim/._segmim_04100.jpg
#   inflating: segmim/segmim_03684.jpg
#   inflating: __MACOSX/segmim/._segmim_03684.jpg
#   inflating: segmim/segmim_01093.jpg
#   inflating: __MACOSX/segmim/._segmim_01093.jpg
#   inflating: segmim/segmim_06924.jpg
#   inflating: __MACOSX/segmim/._segmim_06924.jpg
#   inflating: segmim/segmim_07384.jpg
#   inflating: __MACOSX/segmim/._segmim_07384.jpg
#   inflating: segmim/segmim_04855.jpg
#   inflating: __MACOSX/segmim/._segmim_04855.jpg
#   inflating: segmim/segmim_05593.jpg
#   inflating: __MACOSX/segmim/._segmim_05593.jpg
#   inflating: segmim/segmim_04841.jpg
#   inflating: __MACOSX/segmim/._segmim_04841.jpg
#   inflating: segmim/segmim_05587.jpg
#   inflating: __MACOSX/segmim/._segmim_05587.jpg
#   inflating: segmim/segmim_04699.jpg
#   inflating: __MACOSX/segmim/._segmim_04699.jpg
#   inflating: segmim/segmim_07390.jpg
#   inflating: __MACOSX/segmim/._segmim_07390.jpg
#   inflating: segmim/segmim_01939.jpg
#   inflating: __MACOSX/segmim/._segmim_01939.jpg
#   inflating: segmim/segmim_01087.jpg
#   inflating: __MACOSX/segmim/._segmim_01087.jpg
#   inflating: segmim/segmim_06930.jpg
#   inflating: __MACOSX/segmim/._segmim_06930.jpg
#   inflating: segmim/segmim_00399.jpg
#   inflating: __MACOSX/segmim/._segmim_00399.jpg
#   inflating: segmim/segmim_03690.jpg
#   inflating: __MACOSX/segmim/._segmim_03690.jpg
#   inflating: segmim/segmim_03848.jpg
#   inflating: __MACOSX/segmim/._segmim_03848.jpg
#   inflating: segmim/segmim_06918.jpg
#   inflating: __MACOSX/segmim/._segmim_06918.jpg
#   inflating: segmim/segmim_03860.jpg
#   inflating: __MACOSX/segmim/._segmim_03860.jpg
#   inflating: segmim/segmim_04869.jpg
#   inflating: __MACOSX/segmim/._segmim_04869.jpg
#   inflating: segmim/segmim_01911.jpg
#   inflating: __MACOSX/segmim/._segmim_01911.jpg
#   inflating: segmim/segmim_01905.jpg
#   inflating: __MACOSX/segmim/._segmim_01905.jpg
#   inflating: segmim/segmim_03874.jpg
#   inflating: __MACOSX/segmim/._segmim_03874.jpg

# %%
# Input for the labels of our images
labels = '/content/drive/My Drive/NNDL/group project/imagelabels.mat'
image_labels = loadmat(labels)
image_labels.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'labels'])

# %%
# Adding our image_labels into a dataframe to match with our images
df = pd.DataFrame()
labels = image_labels['labels'].transpose()
labels = labels -1
df = pd.DataFrame(labels, columns = ['image_label'])

# %%
# Adding our image paths to our image_labels dataframe
image_path = []
for i in range (1,len(labels)+1):
  if i<10:
    x = '0000' + str(i)
  elif i<100:
    x = '000' + str(i)
  elif i<1000:
    x = '00' + str(i)
  elif i<10000:
    x = '0' + str(i)
  else:
    break
  image_path.append('/content/segmim/segmim_'+x+'.jpg')

df["image_path"] = image_path

# %%
# Checking how many images we have per class (top few and bottom few to understand the distributioin of samples)
df.image_label.value_counts()
# Out:
# 50    258
# 76    251
# 45    196
# 72    194
# 88    184
#      ...
# 6      40
# 44     40
# 33     40
# 0      40
# 26     40
# Name: image_label, Length: 102, dtype: int64

# %%
# Test to see whether the path code works to open the 1st image
im = Image.open(df['image_path'][0])
width, height = im.size
print(width,height)
# Out:
# 591 500

# %%
# Final check on our data frame before loading the images and converting them to (size, size, 3) numpy pixels
df
# Out:
#       image_label                        image_path
# 0              76  /content/segmim/segmim_00001.jpg
# 1              76  /content/segmim/segmim_00002.jpg
# 2              76  /content/segmim/segmim_00003.jpg
# 3              76  /content/segmim/segmim_00004.jpg
# 4              76  /content/segmim/segmim_00005.jpg
# ...           ...                               ...
# 8184           61  /content/segmim/segmim_08185.jpg
# 8185           61  /content/segmim/segmim_08186.jpg
# 8186           61  /content/segmim/segmim_08187.jpg
# 8187           61  /content/segmim/segmim_08188.jpg
# 8188           61  /content/segmim/segmim_08189.jpg
#
# [8189 rows x 2 columns]

# %%
# Function to load images, convert to numpy array of pixel data, split into train test split, convert to a tensor and return. (Based on img_size input)
def split_function(train_df,img_size):
    gc.collect()

    data = train_df.copy()
    img_size = img_size
    train_image = []
    for i in tqdm(range(data.shape[0])):
      # inputting images with the required input size
      img = image.load_img(data['image_path'][i],target_size=(img_size,img_size,3))
      img = image.img_to_array(img)
      train_image.append(img)
    # appending the image arrays to a new numpy array
    train_df = np.array(train_image)
    image_label = data['image_label'].to_numpy()
    # train, val, test split (0.7, 0.2, 0.1)
    X_train, X_test, y_train, y_test = train_test_split(train_df, image_label, random_state=42, test_size=0.3, stratify = image_label)
    X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, random_state=42, test_size=0.33, stratify = y_test)

    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))

    print('Number of training samples ', len(train_ds))
    print('Number of validation samples ', len(val_ds))

    # Batching and applying prefetching for faster processing
    train_ds = train_ds.cache().batch(32).prefetch(buffer_size = tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.cache().batch(32).prefetch(buffer_size = tf.data.experimental.AUTOTUNE)

    print('Number of training samples after batching ', len(train_ds))
    print('Number of validation samples after batching ', len(val_ds))

    gc.collect()
    
    return(train_ds, val_ds)

# %%
# Fetching all pretrained keras models
all_models_dictionary = {m[0]:m[1] for m in inspect.getmembers(tf.keras.applications, inspect.isfunction)}

# List of all pretrained Keras Model
all_models_dictionary
# Out:
# {'DenseNet121': <function keras.applications.densenet.DenseNet121(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'DenseNet169': <function keras.applications.densenet.DenseNet169(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'DenseNet201': <function keras.applications.densenet.DenseNet201(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'EfficientNetB0': <function keras.applications.efficientnet.EfficientNetB0(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'EfficientNetB1': <function keras.applications.efficientnet.EfficientNetB1(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'EfficientNetB2': <function keras.applications.efficientnet.EfficientNetB2(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'EfficientNetB3': <function keras.applications.efficientnet.EfficientNetB3(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'EfficientNetB4': <function keras.applications.efficientnet.EfficientNetB4(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'EfficientNetB5': <function keras.applications.efficientnet.EfficientNetB5(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'EfficientNetB6': <function keras.applications.efficientnet.EfficientNetB6(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'EfficientNetB7': <function keras.applications.efficientnet.EfficientNetB7(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'EfficientNetV2B0': <function keras.applications.efficientnet_v2.EfficientNetV2B0(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', include_preprocessing=True)>,
#  'EfficientNetV2B1': <function keras.applications.efficientnet_v2.EfficientNetV2B1(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', include_preprocessing=True)>,
#  'EfficientNetV2B2': <function keras.applications.efficientnet_v2.EfficientNetV2B2(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', include_preprocessing=True)>,
#  'EfficientNetV2B3': <function keras.applications.efficientnet_v2.EfficientNetV2B3(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', include_preprocessing=True)>,
#  'EfficientNetV2L': <function keras.applications.efficientnet_v2.EfficientNetV2L(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', include_preprocessing=True)>,
#  'EfficientNetV2M': <function keras.applications.efficientnet_v2.EfficientNetV2M(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', include_preprocessing=True)>,
#  'EfficientNetV2S': <function keras.applications.efficientnet_v2.EfficientNetV2S(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', include_preprocessing=True)>,
#  'InceptionResNetV2': <function keras.applications.inception_resnet_v2.InceptionResNetV2(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'InceptionV3': <function keras.applications.inception_v3.InceptionV3(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'MobileNet': <function keras.applications.mobilenet.MobileNet(input_shape=None, alpha=1.0, depth_multiplier=1, dropout=0.001, include_top=True, weights='imagenet', input_tensor=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'MobileNetV2': <function keras.applications.mobilenet_v2.MobileNetV2(input_shape=None, alpha=1.0, include_top=True, weights='imagenet', input_tensor=None, pooling=None, classes=1000, classifier_activation='softmax', **kwargs)>,
#  'MobileNetV3Large': <function keras.applications.mobilenet_v3.MobileNetV3Large(input_shape=None, alpha=1.0, minimalistic=False, include_top=True, weights='imagenet', input_tensor=None, classes=1000, pooling=None, dropout_rate=0.2, classifier_activation='softmax', include_preprocessing=True)>,
#  'MobileNetV3Small': <function keras.applications.mobilenet_v3.MobileNetV3Small(input_shape=None, alpha=1.0, minimalistic=False, include_top=True, weights='imagenet', input_tensor=None, classes=1000, pooling=None, dropout_rate=0.2, classifier_activation='softmax', include_preprocessing=True)>,
#  'NASNetLarge': <function keras.applications.nasnet.NASNetLarge(input_shape=None, include_top=True, weights='imagenet', input_tensor=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'NASNetMobile': <function keras.applications.nasnet.NASNetMobile(input_shape=None, include_top=True, weights='imagenet', input_tensor=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX002': <function keras.applications.regnet.RegNetX002(model_name='regnetx002', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX004': <function keras.applications.regnet.RegNetX004(model_name='regnetx004', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX006': <function keras.applications.regnet.RegNetX006(model_name='regnetx006', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX008': <function keras.applications.regnet.RegNetX008(model_name='regnetx008', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX016': <function keras.applications.regnet.RegNetX016(model_name='regnetx016', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX032': <function keras.applications.regnet.RegNetX032(model_name='regnetx032', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX040': <function keras.applications.regnet.RegNetX040(model_name='regnetx040', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX064': <function keras.applications.regnet.RegNetX064(model_name='regnetx064', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX080': <function keras.applications.regnet.RegNetX080(model_name='regnetx080', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX120': <function keras.applications.regnet.RegNetX120(model_name='regnetx120', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX160': <function keras.applications.regnet.RegNetX160(model_name='regnetx160', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetX320': <function keras.applications.regnet.RegNetX320(model_name='regnetx320', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY002': <function keras.applications.regnet.RegNetY002(model_name='regnety002', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY004': <function keras.applications.regnet.RegNetY004(model_name='regnety004', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY006': <function keras.applications.regnet.RegNetY006(model_name='regnety006', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY008': <function keras.applications.regnet.RegNetY008(model_name='regnety008', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY016': <function keras.applications.regnet.RegNetY016(model_name='regnety016', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY032': <function keras.applications.regnet.RegNetY032(model_name='regnety032', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY040': <function keras.applications.regnet.RegNetY040(model_name='regnety040', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY064': <function keras.applications.regnet.RegNetY064(model_name='regnety064', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY080': <function keras.applications.regnet.RegNetY080(model_name='regnety080', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY120': <function keras.applications.regnet.RegNetY120(model_name='regnety120', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY160': <function keras.applications.regnet.RegNetY160(model_name='regnety160', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'RegNetY320': <function keras.applications.regnet.RegNetY320(model_name='regnety320', include_top=True, include_preprocessing=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'ResNet101': <function keras.applications.resnet.ResNet101(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, **kwargs)>,
#  'ResNet101V2': <function keras.applications.resnet_v2.ResNet101V2(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'ResNet152': <function keras.applications.resnet.ResNet152(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, **kwargs)>,
#  'ResNet152V2': <function keras.applications.resnet_v2.ResNet152V2(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'ResNet50': <function keras.applications.resnet.ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, **kwargs)>,
#  'ResNet50V2': <function keras.applications.resnet_v2.ResNet50V2(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'ResNetRS101': <function keras.applications.resnet_rs.ResNetRS101(include_top=True, weights='imagenet', classes=1000, input_shape=None, input_tensor=None, pooling=None, classifier_activation='softmax', include_preprocessing=True)>,
#  'ResNetRS152': <function keras.applications.resnet_rs.ResNetRS152(include_top=True, weights='imagenet', classes=1000, input_shape=None, input_tensor=None, pooling=None, classifier_activation='softmax', include_preprocessing=True)>,
#  'ResNetRS200': <function keras.applications.resnet_rs.ResNetRS200(include_top=True, weights='imagenet', classes=1000, input_shape=None, input_tensor=None, pooling=None, classifier_activation='softmax', include_preprocessing=True)>,
#  'ResNetRS270': <function keras.applications.resnet_rs.ResNetRS270(include_top=True, weights='imagenet', classes=1000, input_shape=None, input_tensor=None, pooling=None, classifier_activation='softmax', include_preprocessing=True)>,
#  'ResNetRS350': <function keras.applications.resnet_rs.ResNetRS350(include_top=True, weights='imagenet', classes=1000, input_shape=None, input_tensor=None, pooling=None, classifier_activation='softmax', include_preprocessing=True)>,
#  'ResNetRS420': <function keras.applications.resnet_rs.ResNetRS420(include_top=True, weights='imagenet', classes=1000, input_shape=None, input_tensor=None, pooling=None, classifier_activation='softmax', include_preprocessing=True)>,
#  'ResNetRS50': <function keras.applications.resnet_rs.ResNetRS50(include_top=True, weights='imagenet', classes=1000, input_shape=None, input_tensor=None, pooling=None, classifier_activation='softmax', include_preprocessing=True)>,
#  'VGG16': <function keras.applications.vgg16.VGG16(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'VGG19': <function keras.applications.vgg19.VGG19(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>,
#  'Xception': <function keras.applications.xception.Xception(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000, classifier_activation='softmax')>}

# %%
# List of all pretrained Keras models specifically for image classification
image_pretrained_models = [
        'VGG16',
        'VGG19',
        'ResNet50',
        'ResNet50V2',
        'ResNet101',
        'ResNet101V2',
        'ResNet152',
        'ResNet152V2',
        'MobileNet',
        'MobileNetV2',
        'DenseNet121',
        'DenseNet169',
        'DenseNet201',
        'NASNetMobile',
        'EfficientNetB0',
        'EfficientNetB1',
        'EfficientNetB2',
        'EfficientNetB3',
        'EfficientNetB4',
        'EfficientNetB5',
        'EfficientNetB6',
        'EfficientNetB7',
        'EfficientNetV2B0',
        'EfficientNetV2B1',
        'EfficientNetV2B2',
        'EfficientNetV2B3',
        'EfficientNetV2S',
        'EfficientNetV2M',
        'EfficientNetV2L',
        'Xception',
        'InceptionV3',
        'InceptionResNetV2',
        'NASNetLarge'
    ]

# %%
preprocess_func = { 'VGG16' : tf.keras.applications.vgg16.preprocess_input,
                    'VGG19':tf.keras.applications.vgg19.preprocess_input,
                    'ResNet50':tf.keras.applications.resnet.preprocess_input,
                    'ResNet50V2':tf.keras.applications.resnet_v2.preprocess_input,
                    'ResNet101':tf.keras.applications.resnet.preprocess_input,
                    'ResNet101V2':tf.keras.applications.resnet_v2.preprocess_input,
                    'ResNet152':tf.keras.applications.resnet.preprocess_input,
                    'ResNet152V2':tf.keras.applications.resnet_v2.preprocess_input,
                    'MobileNet':tf.keras.applications.mobilenet.preprocess_input,
                    'MobileNetV2':tf.keras.applications.mobilenet_v2.preprocess_input,
                    'DenseNet121':tf.keras.applications.densenet.preprocess_input,
                    'DenseNet169':tf.keras.applications.densenet.preprocess_input,
                    'DenseNet201':tf.keras.applications.densenet.preprocess_input,
                    'NASNetMobile':tf.keras.applications.nasnet.preprocess_input,
                    'EfficientNetB0':tf.keras.applications.efficientnet.preprocess_input,
                    'EfficientNetB1':tf.keras.applications.efficientnet.preprocess_input,
                    'EfficientNetB2':tf.keras.applications.efficientnet.preprocess_input,
                    'EfficientNetB3':tf.keras.applications.efficientnet.preprocess_input,
                    'EfficientNetB4':tf.keras.applications.efficientnet.preprocess_input,
                    'EfficientNetB5':tf.keras.applications.efficientnet.preprocess_input,
                    'EfficientNetB6':tf.keras.applications.efficientnet.preprocess_input,
                    'EfficientNetB7':tf.keras.applications.efficientnet.preprocess_input,
                    'EfficientNetV2B0':tf.keras.applications.efficientnet_v2.preprocess_input,
                    'EfficientNetV2B1':tf.keras.applications.efficientnet_v2.preprocess_input,
                    'EfficientNetV2B2':tf.keras.applications.efficientnet_v2.preprocess_input,
                    'EfficientNetV2B3':tf.keras.applications.efficientnet_v2.preprocess_input,
                    'EfficientNetV2S':tf.keras.applications.efficientnet_v2.preprocess_input,
                    'EfficientNetV2M':tf.keras.applications.efficientnet_v2.preprocess_input,
                    'EfficientNetV2L':tf.keras.applications.efficientnet_v2.preprocess_input,
                    'Xception': tf.keras.applications.xception.preprocess_input,
                    'InceptionV3':tf.keras.applications.inception_v3.preprocess_input,
                    'InceptionResNetV2':tf.keras.applications.inception_resnet_v2.preprocess_input,
                    'NASNetLarge':tf.keras.applications.nasnet.preprocess_input
                  }

# %%
# Fetching only the models specifically mentioned for image classification
image_models = {image_pretrained_model: all_models_dictionary[image_pretrained_model] for image_pretrained_model in image_pretrained_models}

# Corresponds to Keras documentation for image specific pretrained models
len(image_models)
# Out:
# 33

# %%
# Early stopping implementation to reduce over
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Initialising our augmentation layer
data_augmentation = tf.keras.Sequential([
  keras.layers.RandomFlip("horizontal_and_vertical"),
  keras.layers.RandomRotation(0.2),
])

# %%
train_ds_224, val_ds_224 = split_function(df, 224)
#train_ds_299, val_ds_299 = split_function(df, 299)
#train_ds_331, val_ds_331 = split_function(df, 331)
# Out:
# 100%|██████████| 8189/8189 [00:39<00:00, 206.95it/s]
# Number of training samples  5732
# Number of validation samples  1646
# Number of training samples after batching  180
# Number of validation samples after batching  52

# %%
# Looping over all available image models in Keras
model_benchmarks = {'pretrained_model_name' : [], 'num_params' : [], 'validation_accuracy' : [] }

train_ds, val_ds = train_ds_224, val_ds_224

cnt = 0

for pretrained_model_name, model in tqdm(image_models.items()):
    cnt = cnt+1
    if cnt == 2:
      break
    # Special handling for different pretrained models since they require different image input sizes
    if pretrained_model_name in ['Xception','InceptionV3','InceptionResNetV2'] :
        input_shape=(299, 299, 3)
        train_ds, val_ds = train_ds_299, val_ds_299

    elif pretrained_model_name == 'NASNetLarge':
        input_shape=(331, 331, 3)
        train_ds, val_ds = train_ds_331, val_ds_331

    else :
        input_shape=(224, 224, 3)
        
    # Creating a new model on top
    inputs = tf.keras.layers.Input(shape=input_shape)
    
    #  Float casting
    x = tf.cast(inputs, tf.float32)

    # Data Augmentation 
    x = data_augmentation(x)

    # Default Preprocess Function for our Pre-trained Models
    x = preprocess_func[pretrained_model_name](x)
    
    # Creating our base model
    base_model = model(weights="imagenet", 
                        include_top=False, 
                        input_shape=input_shape)
    # Frezing the base_model weights
    base_model.trainable = False
    
    # Building the model
    x = base_model(x, training = False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)

    outputs = tf.keras.layers.Dense(102, activation='softmax')(x)
    reg_model = tf.keras.Model(inputs, outputs)
    
    reg_model.compile(optimizer=tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    history = reg_model.fit(train_ds, epochs = 20, validation_data=val_ds, callbacks=[es])

    # Saving our models for fine-tuning later in '___________.ipynb'
    # reg_model.save('/content/drive/My Drive/NNDL Project/trained_models/'+pretrained_model_name)
    # reg_model.save(pretrained_model_name)
    
    # Adding model benchmarks to compare later
    model_benchmarks['pretrained_model_name'].append(pretrained_model_name)
    model_benchmarks['num_params'].append(base_model.count_params())
    model_benchmarks['validation_accuracy'].append(history.history['val_accuracy'][-1])
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/20
# 180/180 [==============================] - 31s 129ms/step - loss: 9.4585 - accuracy: 0.1214 - val_loss: 3.6882 - val_accuracy: 0.3548
# Epoch 2/20
# 180/180 [==============================] - 22s 121ms/step - loss: 3.8948 - accuracy: 0.3507 - val_loss: 2.0738 - val_accuracy: 0.5626
# Epoch 3/20
# 180/180 [==============================] - 22s 121ms/step - loss: 2.5678 - accuracy: 0.4934 - val_loss: 1.7276 - val_accuracy: 0.6185
# Epoch 4/20
# 180/180 [==============================] - 22s 121ms/step - loss: 1.9910 - accuracy: 0.5755 - val_loss: 1.4295 - val_accuracy: 0.6707
# Epoch 5/20
# 180/180 [==============================] - 22s 121ms/step - loss: 1.6413 - accuracy: 0.6328 - val_loss: 1.3069 - val_accuracy: 0.7029
# Epoch 6/20
# 180/180 [==============================] - 22s 121ms/step - loss: 1.4147 - accuracy: 0.6677 - val_loss: 1.2115 - val_accuracy: 0.7315
# Epoch 7/20
# 180/180 [==============================] - 22s 121ms/step - loss: 1.2634 - accuracy: 0.6971 - val_loss: 1.1687 - val_accuracy: 0.7321
# Epoch 8/20
# 180/180 [==============================] - 22s 121ms/step - loss: 1.1762 - accuracy: 0.7149 - val_loss: 1.1328 - val_accuracy: 0.7497
# Epoch 9/20
# 180/180 [==============================] - 22s 121ms/step - loss: 1.0384 - accuracy: 0.7341 - val_loss: 1.1124 - val_accuracy: 0.7485
# Epoch 10/20
# 180/180 [==============================] - 22s 121ms/step - loss: 0.9677 - accuracy: 0.7503 - val_loss: 1.0856 - val_accuracy: 0.7631
# Epoch 11/20
# 180/180 [==============================] - 22s 121ms/step - loss: 0.9319 - accuracy: 0.7589 - val_loss: 1.0583 - val_accuracy: 0.7661
# Epoch 12/20
# 180/180 [==============================] - 22s 121ms/step - loss: 0.8975 - accuracy: 0.7680 - val_loss: 1.0698 - val_accuracy: 0.7734
# Epoch 13/20
# 180/180 [==============================] - 22s 120ms/step - loss: 0.8499 - accuracy: 0.7732 - val_loss: 1.0693 - val_accuracy: 0.7625
# Epoch 14/20
# 180/180 [==============================] - 22s 121ms/step - loss: 0.8331 - accuracy: 0.7812 - val_loss: 1.0585 - val_accuracy: 0.7631
#   3%|▎         | 1/33 [06:06<3:15:13, 366.04s/it]

# %%
# Converting model benchmarks to a DataFrame

#(Since our colab notebook crashed we only have the output of one iteration, the remaning results are tablulated in our report)

benchmark_df = pd.DataFrame(model_benchmarks)
benchmark_df.sort_values('validation_accuracy', inplace=True, ascending=False)
benchmark_df
# Out:
#   pretrained_model_name  num_params  validation_accuracy
# 0                 VGG16    14714688             0.763062

# %%
# Saving the benchmarks as a csv to be used for comparison later
benchmark_df.to_csv("transfer_learning_model_results_segmented_good.csv")

# %%
benchmark_df.to_csv("results.csv")
